# %% [markdown]
# <img src="img/ITQ.png" width="500"><br>
# ## Introduccion a Python
# <img src="img/python.png"><br>
# **Nombre:** Alan Velasco, Anderson Soto <br>
# **Fecha:**  7/1/2026

# %%
#Comentarios de python
