# %%
# Ejercicio 1
nombre = "laptop"
precio = 899.99
cantidad = 5
print(f"El producto {nombre} cuesta {precio}€ y quedan {cantidad} unidades")
# Out:
# El producto laptop cuesta 899.99€ y quedan 5 unidades

# %%
N = 27
condicion = (10 <= N <= 50) or (N > 100) or (N < 0 and N % 3 == 0)
print(condicion)
# Out:
# True

# %%
# Ejercicio 3
S1 = "abcdef"
S2 = "cdefgh"
resultado = False
for i in range(len(S1)-2):
    if S1[i:i+3] in S2:
        resultado = True
        break
print(resultado)
# Out:
# True

# %%
# Ejercicio 4
lista = [3, 1, 3, 2, 1, 4]
sin_duplicados = []
for elemento in lista:
    if elemento not in sin_duplicados:
        sin_duplicados.append(elemento)
print(sin_duplicados)
# Out:
# [3, 1, 2, 4]

# %%
# Ejercicio 5
L = ["hola", "mundo", "hola", "python"]
s = "hola"
t = "adiós"
resultado = [t if elemento == s else elemento for elemento in L]
print(resultado)
# Out:
# ['adiós', 'mundo', 'adiós', 'python']

# %% [markdown]
# 2. Dada una lista con elementos duplicados, escribir un programa que muestre una nueva lista
# con el mismo contenido que la primera pero sin elementos duplicados. Para este ejercicio, no
# puedes hacer uso de objetos de tipo ‘Set’.

# %%
x = [2, 3, 5, 5, 9,9 , 10 ,2 ,1]
y = []

for numero in x: #bucle para recorrer la primeralista
    if numero not in y: #condicion para queen caso de que si serepite un numero no lo ponga lalista 
        y.append(numero)# con append hacemos que enla variable y se agregue la nueva lista sin duplicados

print("Original:", x)
print("sin duplicados:", y)
# Out:
# Original: [2, 3, 5, 5, 9, 9, 10, 2, 1]
# sin duplicados: [2, 3, 5, 9, 10, 1]

# %%
x=[4,5,6,8,9,9]
y=[]

for n in x:
    if n not in y:
        y.append(n)

print(y)
# Out:
# [4, 5, 6, 8, 9]

# %%
x=[4,4,5,5,6,9]
y=list(set(x))
print(x)
# Out:
# [4, 4, 5, 5, 6, 9]

# %%
x=5
r=2
m=x+r
print(m)
# Out:
# 7

# %%
# Ejercicio 3
S1 = "abcdef"
S2 = "cdefgh"
resultado = False
for i in range(len(S1)-2):
    if S1[i:i+3] in S2:
        resultado = True
        break
print(resultado)

# %% [markdown]
# s1=
